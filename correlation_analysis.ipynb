# %% [markdown]
# <a href="https://colab.research.google.com/github/encore488/GuardianOwl/blob/main/correlation_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

path_to_data = '/content/renamed_PRAMS.csv'
df = pd.read_csv(path_to_data)

df.info()

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221381 entries, 0 to 221380
# Columns: 251 entries, ID to Maternal height - feet, inches
# dtypes: float64(247), object(4)
# memory usage: 423.9+ MB
#        Hispanic Ethnic Group: 1=NO, 2=YES  \
# count                       214463.000000
# mean                             1.175065
# std                              0.380024
# min                              1.000000
# 25%                              1.000000
# 50%                              1.000000
# 75%                              1.000000
# max                              2.000000
#
#        No. of Cigarettes in 1st Trimester, Daily  \
# count                              219896.000000
# mean                                    0.795444
# std                                     3.621079
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                    98.000000
#
#        No. of Cigarettes in 2nd Trimester, Daily  \
# count                              219898.000000
# mean                                    0.595390
# std                                     3.011245
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                    98.000000
#
#        No. of Cigarettes in 3rd Trimester, Daily  \
# count                              219900.000000
# mean                                    0.527372
# std                                     2.853222
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                    98.000000
#
#        No. of Cigarettes prior to preg, Daily  \
# count                           219912.000000
# mean                                 1.257053
# std                                  5.027313
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                 98.000000
#
#        Baby was born with defect: 1=YES, 2=NO  C-section, 1st: 1=NO, 2=YES  \
# count                           220156.000000                221167.000000
# mean                                 1.995158                     1.202598
# std                                  0.069416                     0.401936
# min                                  1.000000                     1.000000
# 25%                                  2.000000                     1.000000
# 50%                                  2.000000                     1.000000
# 75%                                  2.000000                     1.000000
# max                                  2.000000                     2.000000
#
#        Forceps delivery: 1=NO, 2=YES  Repeated C-section: 1=NO, 2=YES  \
# count                  221207.000000                    221204.000000
# mean                        1.005963                         1.128280
# std                         0.076988                         0.334402
# min                         1.000000                         1.000000
# 25%                         1.000000                         1.000000
# 50%                         1.000000                         1.000000
# 75%                         1.000000                         1.000000
# max                         2.000000                         2.000000
#
#        Vacuum delivery: 1=NO, 2=YES  ...  \
# count                 221207.000000  ...
# mean                       1.024294  ...
# std                        0.153961  ...
# min                        1.000000  ...
# 25%                        1.000000  ...
# 50%                        1.000000  ...
# 75%                        1.000000  ...
# max                        2.000000  ...
#
#        Maternal age grouped: .U=Unknown 17=17 or younger 45=45 or older  \
# count                                      210829.000000
# mean                                           29.238686
# std                                             5.757710
# min                                            17.000000
# 25%                                            25.000000
# 50%                                            29.000000
# 75%                                            33.000000
# max                                            45.000000
#
#        Maternal Race Asian grouped  \
# count                210830.000000
# mean                      1.916364
# std                       0.276842
# min                       1.000000
# 25%                       2.000000
# 50%                       2.000000
# 75%                       2.000000
# max                       2.000000
#
#        Maternal Race Native Hawaiian Other Pacific Islander grouped  \
# count                                      210831.000000
# mean                                            1.986093
# std                                             0.117105
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             2.000000
# 75%                                             2.000000
# max                                             2.000000
#
#        Maternal Race Multiple/Other  \
# count                 210820.000000
# mean                       1.893947
# std                        0.307906
# min                        1.000000
# 25%                        2.000000
# 50%                        2.000000
# 75%                        2.000000
# max                        2.000000
#
#        Maternal Race grouped: .U=UNKNOWN 2=WHITE 3=BLACK 4=AM INDIAN 10=AK NATIVE 21=ASIAN 22=HAWAIIAN/OTH PAC  ISLNDR 23=OTHER/MULTIPLE RACE  \
# count                                      208923.000000
# mean                                            5.891917
# std                                             7.667594
# min                                             2.000000
# 25%                                             2.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                            23.000000
#
#        Paternal Race Asian grouped  \
# count                210214.000000
# mean                      1.933729
# std                       0.248755
# min                       1.000000
# 25%                       2.000000
# 50%                       2.000000
# 75%                       2.000000
# max                       2.000000
#
#        Paternal Race Native Hawaiian Other Pacific Islander grouped  \
# count                                      210215.000000
# mean                                            1.988364
# std                                             0.107240
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             2.000000
# 75%                                             2.000000
# max                                             2.000000
#
#        Paternal Race Multiple/Other  \
# count                 210209.000000
# mean                       1.920279
# std                        0.270861
# min                        1.000000
# 25%                        2.000000
# 50%                        2.000000
# 75%                        2.000000
# max                        2.000000
#
#        Paternal Race grouped: .U=UNKNOWN 2=WHITE 3=BLACK 4=AM INDIAN 10=AK NATIVE 21=ASIAN 22=HAWAIIAN/OTH PACISLNDR 23=OTHER/MULTIPLE RACE  \
# count                                      179439.000000
# mean                                            5.479678
# std                                             7.376057
# min                                             2.000000
# 25%                                             2.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                            23.000000
#
#        Maternal height - feet, inches
# count                   220321.000000
# mean                         5.420478
# std                          0.268093
# min                          0.000000
# 25%                          5.200000
# 50%                          5.400000
# 75%                          5.600000
# max                          8.000000
#
# [8 rows x 247 columns]

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221381 entries, 0 to 221380
# Columns: 251 entries, ID to Maternal height - feet, inches
# dtypes: float64(247), object(4)
# memory usage: 423.9+ MB
#        Hispanic Ethnic Group: 1=NO, 2=YES  \
# count                       214463.000000
# mean                             1.175065
# std                              0.380024
# min                              1.000000
# 25%                              1.000000
# 50%                              1.000000
# 75%                              1.000000
# max                              2.000000
#
#        No. of Cigarettes in 1st Trimester, Daily  \
# count                              219896.000000
# mean                                    0.795444
# std                                     3.621079
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                    98.000000
#
#        No. of Cigarettes in 2nd Trimester, Daily  \
# count                              219898.000000
# mean                                    0.595390
# std                                     3.011245
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                    98.000000
#
#        No. of Cigarettes in 3rd Trimester, Daily  \
# count                              219900.000000
# mean                                    0.527372
# std                                     2.853222
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                    98.000000
#
#        No. of Cigarettes prior to preg, Daily  \
# count                           219912.000000
# mean                                 1.257053
# std                                  5.027313
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                 98.000000
#
#        Baby was born with defect: 1=YES, 2=NO  C-section, 1st: 1=NO, 2=YES  \
# count                           220156.000000                221167.000000
# mean                                 1.995158                     1.202598
# std                                  0.069416                     0.401936
# min                                  1.000000                     1.000000
# 25%                                  2.000000                     1.000000
# 50%                                  2.000000                     1.000000
# 75%                                  2.000000                     1.000000
# max                                  2.000000                     2.000000
#
#        Forceps delivery: 1=NO, 2=YES  Repeated C-section: 1=NO, 2=YES  \
# count                  221207.000000                    221204.000000
# mean                        1.005963                         1.128280
# std                         0.076988                         0.334402
# min                         1.000000                         1.000000
# 25%                         1.000000                         1.000000
# 50%                         1.000000                         1.000000
# 75%                         1.000000                         1.000000
# max                         2.000000                         2.000000
#
#        Vacuum delivery: 1=NO, 2=YES  ...  \
# count                 221207.000000  ...
# mean                       1.024294  ...
# std                        0.153961  ...
# min                        1.000000  ...
# 25%                        1.000000  ...
# 50%                        1.000000  ...
# 75%                        1.000000  ...
# max                        2.000000  ...
#
#        Maternal age grouped: .U=Unknown 17=17 or younger 45=45 or older  \
# count                                      210829.000000
# mean                                           29.238686
# std                                             5.757710
# min                                            17.000000
# 25%                                            25.000000
# 50%                                            29.000000
# 75%                                            33.000000
# max                                            45.000000
#
#        Maternal Race Asian grouped  \
# count                210830.000000
# mean                      1.916364
# std                       0.276842
# min                       1.000000
# 25%                       2.000000
# 50%                       2.000000
# 75%                       2.000000
# max                       2.000000
#
#        Maternal Race Native Hawaiian Other Pacific Islander grouped  \
# count                                      210831.000000
# mean                                            1.986093
# std                                             0.117105
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             2.000000
# 75%                                             2.000000
# max                                             2.000000
#
#        Maternal Race Multiple/Other  \
# count                 210820.000000
# mean                       1.893947
# std                        0.307906
# min                        1.000000
# 25%                        2.000000
# 50%                        2.000000
# 75%                        2.000000
# max                        2.000000
#
#        Maternal Race grouped: .U=UNKNOWN 2=WHITE 3=BLACK 4=AM INDIAN 10=AK NATIVE 21=ASIAN 22=HAWAIIAN/OTH PAC  ISLNDR 23=OTHER/MULTIPLE RACE  \
# count                                      208923.000000
# mean                                            5.891917
# std                                             7.667594
# min                                             2.000000
# 25%                                             2.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                            23.000000
#
#        Paternal Race Asian grouped  \
# count                210214.000000
# mean                      1.933729
# std                       0.248755
# min                       1.000000
# 25%                       2.000000
# 50%                       2.000000
# 75%                       2.000000
# max                       2.000000
#
#        Paternal Race Native Hawaiian Other Pacific Islander grouped  \
# count                                      210215.000000
# mean                                            1.988364
# std                                             0.107240
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             2.000000
# 75%                                             2.000000
# max                                             2.000000
#
#        Paternal Race Multiple/Other  \
# count                 210209.000000
# mean                       1.920279
# std                        0.270861
# min                        1.000000
# 25%                        2.000000
# 50%                        2.000000
# 75%                        2.000000
# max                        2.000000
#
#        Paternal Race grouped: .U=UNKNOWN 2=WHITE 3=BLACK 4=AM INDIAN 10=AK NATIVE 21=ASIAN 22=HAWAIIAN/OTH PACISLNDR 23=OTHER/MULTIPLE RACE  \
# count                                      179439.000000
# mean                                            5.479678
# std                                             7.376057
# min                                             2.000000
# 25%                                             2.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                            23.000000
#
#        Maternal height - feet, inches
# count                   220321.000000
# mean                         5.420478
# std                          0.268093
# min                          0.000000
# 25%                          5.200000
# 50%                          5.400000
# 75%                          5.600000
# max                          8.000000
#
# [8 rows x 247 columns]
